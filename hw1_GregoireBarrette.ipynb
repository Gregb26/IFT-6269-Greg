# %% [markdown]
# # IFT6269 - Homework 1 - Maximum Likelihood Estimation
#
# **Due**: Thursday, September 26th, 2024

# %% [markdown]
# #### Name: Grégoire Barrette
# #### Student ID: 20175180
# #### Collaborators: None

# %% [markdown]
# ### Introduction
#
# In this question, we are going to numerically explore the MLE of the variance parameter of the Gaussian
#
# ### Tasks
# 0.   Get your own copy of this file via "File > Save a copy in Drive...";
# 1.   Fill your personal information and collaborators at the top of this assignment, and rename the notebook accordingly, e.g., `hw1_thomasBayes.ipynb`;
# 2.   Read the instructions provided on each section and cell carefully;
# 3.   Implement the missing features for the functions in section **Playground**;
# 4.   Answer the questions in section **Gaussian Maximum Likelihood Estimation**;
# 5.   Share your notebook with `ift6269.f24@gmail.com` ("Share" button on the top-right corner);
# 6.   Share the link of your notebook on Gradescope ("Share > Copy Link", and paste the link in "Homework 1 (Programming & Checklist)" on Gradescope).
#
# **Important**: You are allowed to collaborate with other students in both the math and coding parts of this assignment. However, the answers provided here must reflect your individual work. For that reason, you are not allowed to share this notebook, except for your submission to the TA for grading. **Don't forget to pin and save the version of the notebook you want to be graded on!**

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %% [markdown]
# ## Playground
#
# You are allowed to add as many cells and functions as you wish in this section, but not allowed to change the signature (name and inputs) of the provided functions! Please add all your new auxiliary functions here.

# %% [markdown]
# I will find the MLE estimator for $\mu$ and $\sigma^2$ using Gradient Descent. First, each trial is independently and identically distributed according to a standard normal definition: $X_i\sim \mathcal{N(0,1)}$. So the joint distribution for $n$ trials is
# $$p(x_1, \dots, x_n; \mu, \sigma^2) = \prod_{i=1}^n\frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x_i-\mu)^2}{2\sigma^2}}.$$
# Usually, we find the MLE by maximizing the $\log$ of $p(x_1,\dots, x_n)$ with respect to the parameters. Here, I will recast this into a minimization problem so I can use gradient descent. This translates to minimizing the negative log-lilkelyhood $\ell(\mu, \sigma^2) = -\log p(x_1,\dots, x_n; \mu, \sigma^2)$.
# \begin{align*}
# \ell(\mu, \sigma^2) = -\log p(x_1,\dots, x_n; \mu, \sigma^2) &= -\log\left(\prod_{i=1}^n\frac{1}{\sqrt{2\pi\sigma^2}}e^{-\frac{(x_i-\mu)^2}{2\sigma^2}}\right),\\
# &= -\sum_{i=1}^n\left(-\frac{1}{2}\log(2\pi\sigma^2) + \log\left(e^{-\frac{(x_i-\mu)^2}{2\sigma^2}}\right)\right),\\
# &=\frac{n}{2}\log(2\pi\sigma^2)+\sum_{i=1}^n\frac{1}{2\sigma^2}(x_i-\mu)^2.
# \end{align*}
#
# I will need the gradients with respect to the parameters $\mu$ and $\sigma^2$. Let's compute them:
# $$\frac{\partial\ell(\mu,\sigma^2)}{\partial\mu} = -\sum_{i=1}^n\frac{x_i-\mu}{\sigma^2},$$
# and
# $$\frac{\partial\ell(\mu,\sigma^2)}{\partial\sigma^2} = \frac{n}{\sigma} - \sum_{i=1}^n\frac{(x_i-\mu)^2}{\sigma^4}.$$
#
# Then, the gradient descent algorithm proposes a new point $(\mu_{i+1},\,\sigma_{i+1}^2)$ based on the gradient computed at the previous points and the learning rate $\varepsilon$:
# $$(\mu_{i+1},\,\sigma_{i+1}^2) = (\mu_i - \varepsilon\frac{\partial\ell(\mu,\sigma^2)}{\partial\mu},\, \sigma_i^2 -\varepsilon\frac{\partial\ell(\mu,\sigma^2)}{\partial\sigma^2}).$$

# %%
def sample_gaussian_data(num_samples, num_trials):
    """
    
    Generate num_trials sets of samples of a *standard* 1-d Gaussian random variable.
    Each set of samples contains num_sample samples

        Inputs:
            num_samples: [int] Number of samples to generate per trial
            num_trials: [int] Number of trials to generate

        Returns:
            samples: [num_samples, num_trials] Vector of generated samples
    """

    samples = np.random.normal(0, 1, (num_samples, num_trials))

    return samples

def mu_sigma2_mle(samples):
    """
   
    Compute Gaussian MLE estimators for the mean and variance
        Inputs:
             samples: [num_samples, num_trials] Matrix of N(0, 1) iid samples.
                      It contains num_trials sets, each of these sets containing
                      num_samples samples.

        Returns:
             mu_hat: [num_trials] Vector of MLE mean estimators for each trial
             sigma2_hat: [num_trials] Vector of MLE variance estimators for each trial

    """
    # Useful dimensions
    num_samples, num_trials = samples.shape

    mu_hat = np.zeros(num_trials)
    sigma2_hat = np.zeros(num_trials)

    # gradient descent parameters
    lr = 1e-3 # learning rate
    tol = 1e-6 # tolerance
    max = 100000 # maximum number of iterations

    # initial (educated) guesses for mean and variance 
    mu = 0
    sigma2 = 1

    # loop over all trials
    for i in range(num_trials):
        
        # gradient descent loop
        step = 0
        for j in range(max):
            # compute the gradients
            grad_mu = -(1 / sigma2**2) * np.sum(samples[:,i] - mu)
            grad_sigma2 = (num_samples / sigma2) - (1 / sigma2**4) * np.sum((samples[:,i] - mu)**2)
        
            # gradient descent step
            new_mu = mu - lr * grad_mu
            new_sigma2 = sigma2 - lr * grad_sigma2

            # ensuring sigma2 is positive
            if new_sigma2 <= 0:
                new_sigma2 = 1e-6

            # check for convergence
            if (np.abs(mu - new_mu) < tol) and (np.abs(sigma2 - new_sigma2) < tol):
                break

            # update to new values
            mu = new_mu
            sigma2 = new_sigma2 
            step += 1
        
        mu_hat[i] = mu
        sigma2_hat[i] = sigma2
        print(sigma2)

        print('Trial ', i+1, ' converged in ', step, ' steps.')

    return mu_hat, sigma2_hat

def freq_mean_var(x):
    """
    Compute the frequentist mean and variance of a vector of n real numbers
        Inputs:
             x: [n] Vector of real numbers

        Returns:
             (mean, var): [tuple] Frequentist mean and variance of x

    """

    n = x.shape[0]

    mean = (1 / n)*np.sum(x)
    var = (1 / n)*np.sum((x - mean)**2)

    return mean, var

def empirical_frequentist_bias(empirical_mean, true_mean):
    """
    
    Estimate the frequentist bias of an estimator given its empirical and true means
        Inputs:
             true_mean: [float] True mean of the estimator
             empirical_mean: [float] Empirical mean of the estimator

        Returns:
             bias: [float] Frequentist bias

    """

    # computing the bias
    bias = true_mean - empirical_mean

    return bias

def plot_sigma_hat_histogram(samples, bins=200):
    """
    Plots a histogram of a estimated variances
        Inputs:
            samples: [array] Estimated variances to be plotted

    """
    # Plot histogram with custom bins for readability.
    plt.hist(samples, bins=bins, alpha=0.8, label=r'$\hat{\sigma}$' +' histogram');
    plt.ylabel('Counts')
    plt.xlim(0,5)
    plt.xlabel(r'$\hat{\sigma^2}$')
    plt.legend();

# %% [markdown]
# ## Gaussian Maximum Likelihood Estimation

# %% [markdown]
# In this section **DO NOT** change the code in any of the cells, unless explicitly stated. Simply answer the questions in the corresponding text cells after having executed your implementation. If you have respected the signature of the functions above in terms of inputs and outputs, your code should run.

# %% [markdown]
# ### Sample generation
#
# Use the functions defined above to draw $n=5$ samples from the standard Gaussian distribution, $\mathcal{N}(0,1)$.

# %%
NUM_SAMPLES = 5

samples = sample_gaussian_data(num_samples=NUM_SAMPLES, num_trials=1)

print('Generated Gaussian samples')
print(samples)
# Out:
# Generated Gaussian samples
# [[-1.32329418]
#  [ 0.69343637]
#  [-0.68657574]
#  [-0.04763579]
#  [-0.10441248]]

# %% [markdown]
# ### MLE computation
# Compute the ML estimate $\hat{\mu}$ for the mean and $\hat{\sigma}^2$ for the variance of the Gaussian, as given in Question 3(d).

# %%
mu_hat, sigma2_hat = mu_sigma2_mle(samples)

print('MLE mean - variance')
print(mu_hat, sigma2_hat)
# Out:
# 0.7702884515952119
# Trial  1  converged in  960  steps.
# MLE mean - variance
# [-0.29357824] [0.77028845]

# %% [markdown]
# ### MLE computation
# Repeat the previous steps 10,000 times.  Plot a histogram of the 10,000 estimates of the Gaussian  variance  parameter  to  show  its  empirical  distribution.

# %%
NUM_TRIALS = int(1e4)
samples = sample_gaussian_data(num_samples=NUM_SAMPLES, num_trials=NUM_TRIALS)
_, sigma2_hat_vec = mu_sigma2_mle(samples)
# Out:
# 0.9409942783746008
# Trial  1  converged in  1418  steps.
# 0.7929623151977899
# Trial  2  converged in  462  steps.
# 1.046932068899073
# Trial  3  converged in  1754  steps.
# 1.0978774434755507
# Trial  4  converged in  1632  steps.
# 0.7822261807987005
# Trial  5  converged in  1000  steps.
# 0.7939578241288214
# Trial  6  converged in  895  steps.
# 0.8475756125891408
# Trial  7  converged in  1175  steps.
# 0.5375627796040567
# Trial  8  converged in  454  steps.
# 0.7260063521381684
# Trial  9  converged in  765  steps.
# 0.6400046007628681
# Trial  10  converged in  625  steps.
# 0.510708126464991
# Trial  11  converged in  604  steps.
# 0.783844421168942
# Trial  12  converged in  838  steps.
# 1.122780033997562
# Trial  13  converged in  1924  steps.
# 0.9483328063888937
# Trial  14  converged in  1708  steps.
# 1.127059710580697
# Trial  15  converged in  1546  steps.
# 0.9356162341113842
# Trial  16  converged in  854  steps.
# 0.9969994606309364
# Trial  17  converged in  1585  steps.
# 0.6646018437240818
# Trial  18  converged in  784  steps.
# 0.4934510876068312
# Trial  19  converged in  424  steps.
# 0.6510488660650372
# Trial  20  converged in  718  steps.
# 0.910317198502554
# Trial  21  converged in  1270  steps.
# 1.0842388452535416
# Trial  22  converged in  1419  steps.
# 0.8682722421507578
# Trial  23  converged in  1367  steps.
# 0.7287694740007793
# Trial  24  converged in  789  steps.
# 0.8558378137870472
# Trial  25  converged in  1169  steps.
# 0.707839727356363
# Trial  26  converged in  1055  steps.
# 1.2460186563073552
# Trial  27  converged in  2669  steps.
# 0.7224571247281785
# Trial  28  converged in  964  steps.
# 0.9672037816094404
# Trial  29  converged in  1439  steps.
# 0.999100445331791
# Trial  30  converged in  1819  steps.
# 0.6714882086090735
# Trial  31  converged in  920  steps.
# 0.579152488505848
# Trial  32  converged in  502  steps.
# 0.9880900561665172
# Trial  33  converged in  1508  steps.
# 0.7211701936342071
# Trial  34  converged in  950  steps.
# 0.9610381292030472
# Trial  35  converged in  1397  steps.
# 0.9641070548384992
# Trial  36  converged in  1521  steps.
# 0.9515257950675904
# Trial  37  converged in  1465  steps.
# 0.6189896757587239
# Trial  38  converged in  638  steps.
# 0.8114891854156224
# Trial  39  converged in  986  steps.
# 0.8351292843986008
# Trial  40  converged in  1144  steps.
# 0.5422233462084448
# Trial  41  converged in  531  steps.
# 0.9077766326113151
# Trial  42  converged in  1369  steps.
# 0.8539824871385399
# Trial  43  converged in  1085  steps.
# 1.1714424507665462
# Trial  44  converged in  2359  steps.
# 0.9687138217884476
# Trial  45  converged in  1716  steps.
# 0.5846078103304796
# Trial  46  converged in  639  steps.
# 1.0633303286149902
# Trial  47  converged in  1911  steps.
# 0.656114567775033
# Trial  48  converged in  1066  steps.
# 0.6830233510391966
# Trial  49  converged in  1023  steps.
# 0.5075736622530165
# Trial  50  converged in  644  steps.
# 0.7548313136174387
# Trial  51  converged in  995  steps.
# 1.1537438541990348
# Trial  52  converged in  998  steps.
# 1.250508428910269
# Trial  53  converged in  2388  steps.
# 0.8685976663440362
# Trial  54  converged in  1438  steps.
# 0.7260769470296339
# Trial  55  converged in  760  steps.
# 1.356246431211478
# Trial  56  converged in  2439  steps.
# 0.39516901333179194
# Trial  57  converged in  467  steps.
# 0.9460944712443401
# Trial  58  converged in  1552  steps.
# 0.956151212259705
# Trial  59  converged in  1101  steps.
# 0.8196304115237361
# Trial  60  converged in  1209  steps.
# 1.3142082958100658
# Trial  61  converged in  2731  steps.
# 0.7496437415824264
# Trial  62  converged in  1089  steps.
# 0.8966298992501641
# Trial  63  converged in  1160  steps.
# 0.7674184739903351
# Trial  64  converged in  1155  steps.
# 1.5810459563442358
# Trial  65  converged in  3656  steps.
# 0.917926023260914
# Trial  66  converged in  1429  steps.
# 1.1610641028818818
# Trial  67  converged in  1841  steps.
# 1.0163869039664344
# Trial  68  converged in  1757  steps.
# 0.8891622708867485
# Trial  69  converged in  1386  steps.
# 0.8321817691326034
# Trial  70  converged in  1268  steps.
# 0.7256347840152582
# Trial  71  converged in  1066  steps.
# 0.8207482506055439
# Trial  72  converged in  914  steps.
# 0.7493074802126459
# Trial  73  converged in  954  steps.
# 0.3603916093914494
# Trial  74  converged in  491  steps.
# 0.826490727032443
# Trial  75  converged in  1229  steps.
# 1.1659975792618833
# Trial  76  converged in  2115  steps.
# 0.9347785798471169
# Trial  77  converged in  1519  steps.
# 0.40775463387517336
# Trial  78  converged in  534  steps.
# 0.9698222841215917
# Trial  79  converged in  1626  steps.
# 0.768597948390379
# Trial  80  converged in  832  steps.
# 0.9204615337893125
# Trial  81  converged in  1236  steps.
# 0.49779060892088145
# Trial  82  converged in  332  steps.
# 0.5084323269537461
# Trial  83  converged in  436  steps.
# 0.8156079536809532
# Trial  84  converged in  1173  steps.
# 0.7468409978825675
# Trial  85  converged in  994  steps.
# 1.1168050081051184
# Trial  86  converged in  626  steps.
# 0.7404979032491726
# Trial  87  converged in  906  steps.
# 0.5121424416302555
# Trial  88  converged in  460  steps.
# 0.9953671957235063
# Trial  89  converged in  1582  steps.
# 0.9162597812193877
# Trial  90  converged in  1265  steps.
# 0.9979867756965841
# Trial  91  converged in  1756  steps.
# 0.8185838453881498
# Trial  92  converged in  1313  steps.
# 0.9613042133832098
# Trial  93  converged in  1307  steps.
# 0.7021563757426391
# Trial  94  converged in  864  steps.
# 0.7560193140919892
# Trial  95  converged in  1061  steps.
# 1.1289370099793052
# Trial  96  converged in  2149  steps.
# 0.9999648757020957
# Trial  97  converged in  1440  steps.
# 1.027509852191829
# Trial  98  converged in  1482  steps.
# 0.6800620672638524
# Trial  99  converged in  671  steps.
# 0.6174895167741722
# Trial  100  converged in  624  steps.
# 0.6052043736830746
# Trial  101  converged in  912  steps.
# 0.9676009207058668
# Trial  102  converged in  1661  steps.
# 0.5209173039141723
# Trial  103  converged in  643  steps.
# 0.5946132413662152
# Trial  104  converged in  641  steps.
# 1.2229177204444805
# Trial  105  converged in  2274  steps.
# 0.7158050641159053
# Trial  106  converged in  979  steps.
# 1.0846391132232012
# Trial  107  converged in  775  steps.
# 0.9719494485741071
# Trial  108  converged in  1503  steps.
# 0.8633478701267909
# Trial  109  converged in  492  steps.
# 1.0034484280068272
# Trial  110  converged in  1201  steps.
# 0.9431878078145409
# Trial  111  converged in  1323  steps.
# 1.0366087797501673
# Trial  112  converged in  1785  steps.
# 0.9652741405937383
# Trial  113  converged in  1707  steps.
# 0.8307801264325763
# Trial  114  converged in  1061  steps.
# 0.6823808170824561
# Trial  115  converged in  758  steps.
# 0.6521732419541384
# Trial  116  converged in  660  steps.
# 0.9101173059649591
# Trial  117  converged in  1332  steps.
# 0.8915086406670124
# Trial  118  converged in  1412  steps.
# 1.1104752532544486
# Trial  119  converged in  1862  steps.
# 0.8419380120847823
# Trial  120  converged in  1179  steps.
# 0.9289417505795522
# Trial  121  converged in  1200  steps.
# 0.7272006980068414
# Trial  122  converged in  852  steps.
# 0.567700676988247
# Trial  123  converged in  540  steps.
# 1.0354307693803049
# Trial  124  converged in  1688  steps.
# 0.6450991331526315
# Trial  125  converged in  697  steps.
# 0.6863209184756524
# Trial  126  converged in  891  steps.
# 0.524225484257623
# Trial  127  converged in  472  steps.
# 1.1462750669210522
# Trial  128  converged in  1845  steps.
# 1.0669934508389163
# Trial  129  converged in  1481  steps.
# 0.9477683356798854
# Trial  130  converged in  1020  steps.
# 1.2104694676555499
# Trial  131  converged in  1463  steps.
# 0.6644742969320321
# Trial  132  converged in  951  steps.
# 0.9047000940196318
# Trial  133  converged in  1439  steps.
# 0.9942632249371116
# Trial  134  converged in  1632  steps.
# 0.8030919873862684
# Trial  135  converged in  1332  steps.
# 0.9126805383110521
# Trial  136  converged in  1511  steps.
# 1.131008844289573
# Trial  137  converged in  2096  steps.
# 0.8328613422522021
# Trial  138  converged in  1127  steps.
# 0.7783766767380101
# Trial  139  converged in  1035  steps.
# 1.1109540960256357
# Trial  140  converged in  2093  steps.
# 0.5444269939325986
# Trial  141  converged in  780  steps.
# 0.909072866971215
# Trial  142  converged in  1199  steps.
# 0.9212197938320862
# Trial  143  converged in  1340  steps.
# 0.7850462981424607
# Trial  144  converged in  1075  steps.
# 0.8618373156487459
# Trial  145  converged in  1244  steps.
# 0.40278275182030415
# Trial  146  converged in  519  steps.
# 0.7811713230079227
# Trial  147  converged in  961  steps.
# 0.7904137453486376
# Trial  148  converged in  1075  steps.
# 0.7026291430170709
# Trial  149  converged in  1044  steps.
# 0.7856732860901866
# Trial  150  converged in  1124  steps.
# 0.8924322216608968
# Trial  151  converged in  1082  steps.
# 0.36865353279145785
# Trial  152  converged in  367  steps.
# 0.9345312164939065
# Trial  153  converged in  1077  steps.
# 1.1924539835696215
# Trial  154  converged in  1241  steps.
# 0.9594742955733382
# Trial  155  converged in  1111  steps.
# 0.4277238122829516
# Trial  156  converged in  365  steps.
# 0.6050834236222401
# Trial  157  converged in  757  steps.
# 1.2151783980353401
# Trial  158  converged in  2096  steps.
# 0.9293913777400262
# Trial  159  converged in  1003  steps.
# 0.7506411909091336
# Trial  160  converged in  784  steps.
# 0.5636132797880092
# Trial  161  converged in  602  steps.
# 0.9366557446294482
# Trial  162  converged in  1034  steps.
# 0.7294026975645469
# Trial  163  converged in  866  steps.
# 0.8920780314548267
# Trial  164  converged in  1143  steps.
# 1.3541329098961787
# Trial  165  converged in  2634  steps.
# 0.8954431568581293
# Trial  166  converged in  1309  steps.
# 0.7278382413469822
# Trial  167  converged in  988  steps.
# 0.8453766886552516
# Trial  168  converged in  1133  steps.
# 0.5555856985247084
# Trial  169  converged in  629  steps.
# 0.638412463122599
# Trial  170  converged in  772  steps.
# 1.3293410166426884
# Trial  171  converged in  2880  steps.
# 1.113145261096212
# Trial  172  converged in  1968  steps.
# 0.6252477990897293
# Trial  173  converged in  803  steps.
# 1.004072297945654
# Trial  174  converged in  1712  steps.
# 0.8904633904498058
# Trial  175  converged in  1456  steps.
# 0.6189600433367412
# Trial  176  converged in  661  steps.
# 1.078409952594823
# Trial  177  converged in  1635  steps.
# 0.7223445712806821
# Trial  178  converged in  788  steps.
# 0.7211536702811806
# Trial  179  converged in  722  steps.
# 0.707333754301734
# Trial  180  converged in  781  steps.
# 0.6744461111625344
# Trial  181  converged in  688  steps.
# 0.8862549513228031
# Trial  182  converged in  1151  steps.
# 0.8532216502844402
# Trial  183  converged in  1184  steps.
# 0.9159738789075532
# Trial  184  converged in  1265  steps.
# 0.7596679093256693
# Trial  185  converged in  981  steps.
# 0.5294862848880636
# Trial  186  converged in  508  steps.
# 0.6626449688663041
# Trial  187  converged in  674  steps.
# 0.4495321065874444
# Trial  188  converged in  433  steps.
# 0.6090132820058769
# Trial  189  converged in  605  steps.
# 0.9532420453993646
# Trial  190  converged in  1333  steps.
# 0.9128342528647464
# Trial  191  converged in  1352  steps.
# 1.0337926010935639
# Trial  192  converged in  844  steps.
# 0.8141582810839116
# Trial  193  converged in  1164  steps.
# 0.805328585403239
# Trial  194  converged in  1130  steps.
# 0.9467653411101647
# Trial  195  converged in  1504  steps.
# 0.6370587827279569
# Trial  196  converged in  772  steps.
# 0.9080177264683457
# Trial  197  converged in  1184  steps.
# 0.8645131043843612
# Trial  198  converged in  1173  steps.
# 0.9360003085924945
# Trial  199  converged in  590  steps.
# 0.8185782517184605
# Trial  200  converged in  906  steps.
# 1.1215440960276324
# Trial  201  converged in  1334  steps.
# 0.3950125125051493
# Trial  202  converged in  449  steps.
# 1.0110229577660335
# Trial  203  converged in  1608  steps.
# 0.7349502765811169
# Trial  204  converged in  951  steps.
# 0.6876274785238461
# Trial  205  converged in  811  steps.
# 0.7286754748615348
# Trial  206  converged in  778  steps.
# 0.7554640659511695
# Trial  207  converged in  726  steps.
# 1.0203533783122865
# Trial  208  converged in  1858  steps.
# 1.0684915185813346
# Trial  209  converged in  2042  steps.
# 1.0427353728396083
# Trial  210  converged in  1331  steps.
# 0.8422521321811803
# Trial  211  converged in  1119  steps.
# 0.8923376928986354
# Trial  212  converged in  1302  steps.
# 0.7991186716071529
# Trial  213  converged in  1031  steps.
# 0.7762384504105851
# Trial  214  converged in  1088  steps.
# 0.4958227942352259
# Trial  215  converged in  344  steps.
# 1.0454209321048202
# Trial  216  converged in  1461  steps.
# 0.7292591587248417
# Trial  217  converged in  1016  steps.
# 1.1752171042303912
# Trial  218  converged in  1856  steps.
# 1.0146130281066417
# Trial  219  converged in  1601  steps.
# 0.39000760137863993
# Trial  220  converged in  416  steps.
# 0.8684322141465499
# Trial  221  converged in  1110  steps.
# 0.9936516753355835
# Trial  222  converged in  1384  steps.
# 0.65574071902015
# Trial  223  converged in  926  steps.
# 0.6878909102956074
# Trial  224  converged in  722  steps.
# 0.6600178669621299
# Trial  225  converged in  798  steps.
# 0.9805984411419271
# Trial  226  converged in  1456  steps.
# 0.7690726937469421
# Trial  227  converged in  727  steps.
# 0.901128488244556
# Trial  228  converged in  1131  steps.
# 0.7444105424624592
# Trial  229  converged in  1054  steps.
# 0.6834584548835377
# Trial  230  converged in  861  steps.
# 0.8847228328901707
# Trial  231  converged in  1388  steps.
# 1.2167126147680525
# Trial  232  converged in  1882  steps.
# 0.7307212690073328
# Trial  233  converged in  907  steps.
# 0.8793530722995184
# Trial  234  converged in  1175  steps.
# 0.7127320094633818
# Trial  235  converged in  816  steps.
# 0.6559184178475792
# Trial  236  converged in  899  steps.
# 1.0511826188242261
# Trial  237  converged in  1964  steps.
# 1.232226515942653
# Trial  238  converged in  1760  steps.
# 0.7357328606179903
# Trial  239  converged in  1025  steps.
# 0.5934759023191024
# Trial  240  converged in  264  steps.
# 1.042266678775399
# Trial  241  converged in  1404  steps.
# 0.7577753478304903
# Trial  242  converged in  979  steps.
# 0.727658719529264
# Trial  243  converged in  914  steps.
# 0.9234800254144456
# Trial  244  converged in  658  steps.
# 0.959975031411417
# Trial  245  converged in  1746  steps.
# 0.9684478863129026
# Trial  246  converged in  1243  steps.
# 0.7566646548946699
# Trial  247  converged in  915  steps.
# 0.6898945568664813
# Trial  248  converged in  833  steps.
# 1.0163674394324969
# Trial  249  converged in  1808  steps.
# 1.0748692762939518
# Trial  250  converged in  2191  steps.
# 0.642962686377586
# Trial  251  converged in  960  steps.
# 0.6949547934728092
# Trial  252  converged in  787  steps.
# 0.9644495011531974
# Trial  253  converged in  1424  steps.
# 0.8309488182346743
# Trial  254  converged in  894  steps.
# 0.92655044212623
# Trial  255  converged in  1462  steps.
# 0.6768945018976728
# Trial  256  converged in  909  steps.
# 0.4705854792256241
# Trial  257  converged in  451  steps.
# 1.0153851075989209
# Trial  258  converged in  1492  steps.
# 1.1201925511347577
# Trial  259  converged in  1926  steps.
# 0.8774810958256363
# Trial  260  converged in  937  steps.
# 0.7974168632000325
# Trial  261  converged in  1032  steps.
# 0.6316326115502269
# Trial  262  converged in  907  steps.
# 0.8038940673823263
# Trial  263  converged in  1042  steps.
# 0.9145549219598553
# Trial  264  converged in  1087  steps.
# 1.0713934636253113
# Trial  265  converged in  1620  steps.
# 0.6297906769329483
# Trial  266  converged in  754  steps.
# 1.277122034739105
# Trial  267  converged in  2418  steps.
# 0.8984358811090871
# Trial  268  converged in  1179  steps.
# 1.3489639681240253
# Trial  269  converged in  2420  steps.
# 0.7032635964036998
# Trial  270  converged in  864  steps.
# 1.0652583990854712
# Trial  271  converged in  1436  steps.
# 0.46762057954756886
# Trial  272  converged in  429  steps.
# 0.8795305299825029
# Trial  273  converged in  1160  steps.
# 0.7872019761733764
# Trial  274  converged in  868  steps.
# 0.9773719546565768
# Trial  275  converged in  1467  steps.
# 0.7130345411797976
# Trial  276  converged in  838  steps.
# 0.5214280272877817
# Trial  277  converged in  503  steps.
# 0.792354974572989
# Trial  278  converged in  1044  steps.
# 0.9410664323311273
# Trial  279  converged in  1456  steps.
# 0.8853095523134344
# Trial  280  converged in  1467  steps.
# 0.8655397636128052
# Trial  281  converged in  1389  steps.
# 0.7659715520470813
# Trial  282  converged in  1262  steps.
# 0.9822321871449712
# Trial  283  converged in  1798  steps.
# 0.6326616489997234
# Trial  284  converged in  768  steps.
# 0.8736059218084032
# Trial  285  converged in  1060  steps.
# 1.4783248007529513
# Trial  286  converged in  2576  steps.
# 0.7701524267854262
# Trial  287  converged in  1061  steps.
# 0.7003326772740439
# Trial  288  converged in  1058  steps.
# 0.6191533654089018
# Trial  289  converged in  677  steps.
# 0.7879502803110027
# Trial  290  converged in  1025  steps.
# 1.0409270747196757
# Trial  291  converged in  1577  steps.
# 0.9926494572883192
# Trial  292  converged in  1680  steps.
# 0.7200268283671634
# Trial  293  converged in  777  steps.
# 0.9842077174437791
# Trial  294  converged in  1488  steps.
# 1.2688566034394781
# Trial  295  converged in  1966  steps.
# 0.3539778394283784
# Trial  296  converged in  456  steps.
# 0.8134886520373015
# Trial  297  converged in  745  steps.
# 1.2141723632739903
# Trial  298  converged in  2204  steps.
# 0.8554283428156549
# Trial  299  converged in  1194  steps.
# 0.6083725313391617
# Trial  300  converged in  701  steps.
# 1.161624686563115
# Trial  301  converged in  1993  steps.
# 0.8732601836221059
# Trial  302  converged in  1232  steps.
# 1.0203469806765966
# Trial  303  converged in  1564  steps.
# 0.785757124710547
# Trial  304  converged in  1103  steps.
# 0.606530141076613
# Trial  305  converged in  675  steps.
# 0.8661678995370797
# Trial  306  converged in  1100  steps.
# 0.5785345045611321
# Trial  307  converged in  526  steps.
# 1.0330764942505148
# Trial  308  converged in  1438  steps.
# 0.7132162176620747
# Trial  309  converged in  910  steps.
# 0.9513776497572348
# Trial  310  converged in  1577  steps.
# 1.1048955218578107
# Trial  311  converged in  1269  steps.
# 0.5971662249607194
# Trial  312  converged in  772  steps.
# 1.313888578466563
# Trial  313  converged in  2254  steps.
# 0.7331988576881413
# Trial  314  converged in  1036  steps.
# 1.0234402498241983
# Trial  315  converged in  1398  steps.
# 0.9791692020559141
# Trial  316  converged in  1772  steps.
# 0.6910513718986794
# Trial  317  converged in  942  steps.
# 0.6385505321249665
# Trial  318  converged in  745  steps.
# 0.9855631935985313
# Trial  319  converged in  1290  steps.
# 1.0823638861860143
# Trial  320  converged in  2071  steps.
# 0.8764962719005044
# Trial  321  converged in  1248  steps.
# 0.7751863550261936
# Trial  322  converged in  921  steps.
# 1.2309080375743227
# Trial  323  converged in  2163  steps.
# 0.7106713258514797
# Trial  324  converged in  990  steps.
# 0.5619261039160642
# Trial  325  converged in  588  steps.
# 1.2368568348589504
# Trial  326  converged in  1757  steps.
# 0.8125596643765014
# Trial  327  converged in  1309  steps.
# 1.0522263203870055
# Trial  328  converged in  2044  steps.
# 1.1558918751561182
# Trial  329  converged in  1953  steps.
# 0.8179803846414186
# Trial  330  converged in  1389  steps.
# 0.6963146475904886
# Trial  331  converged in  917  steps.
# 0.8417391908735595
# Trial  332  converged in  1283  steps.
# 0.9778143058327815
# Trial  333  converged in  1637  steps.
# 0.741250210872194
# Trial  334  converged in  973  steps.
# 0.6703666654571174
# Trial  335  converged in  856  steps.
# 0.7238587091515417
# Trial  336  converged in  653  steps.
# 0.9160056728009288
# Trial  337  converged in  1531  steps.
# 0.6785088910490717
# Trial  338  converged in  772  steps.
# 0.8896853419856904
# Trial  339  converged in  564  steps.
# 0.9519587883768734
# Trial  340  converged in  1680  steps.
# 0.8366271963284565
# Trial  341  converged in  1323  steps.
# 1.0602458837278999
# Trial  342  converged in  1279  steps.
# 0.7925682305071315
# Trial  343  converged in  675  steps.
# 1.0686968877097924
# Trial  344  converged in  1301  steps.
# 1.2178926537538264
# Trial  345  converged in  2121  steps.
# 0.8441176620341485
# Trial  346  converged in  1237  steps.
# 0.9820982250970403
# Trial  347  converged in  1385  steps.
# 0.9263116556094991
# Trial  348  converged in  1328  steps.
# 0.7627358824667557
# Trial  349  converged in  823  steps.
# 0.8331068606394517
# Trial  350  converged in  1269  steps.
# 1.1471614762102889
# Trial  351  converged in  1624  steps.
# 1.413698916879124
# Trial  352  converged in  1979  steps.
# 0.893334102964311
# Trial  353  converged in  1439  steps.
# 1.1525406278412729
# Trial  354  converged in  1813  steps.
# 0.7917094299888184
# Trial  355  converged in  1275  steps.
# 0.17986369730012083
# Trial  356  converged in  213  steps.
# 0.8360578660406174
# Trial  357  converged in  2009  steps.
# 0.5567414102423436
# Trial  358  converged in  690  steps.
# 0.7527575890654987
# Trial  359  converged in  1080  steps.
# 0.6152201608200394
# Trial  360  converged in  614  steps.
# 1.016983241320183
# Trial  361  converged in  1549  steps.
# 1.2818103827384941
# Trial  362  converged in  2513  steps.
# 1.1865288884675218
# Trial  363  converged in  1973  steps.
# 0.5044977759553835
# Trial  364  converged in  517  steps.
# 0.8414313999940087
# Trial  365  converged in  1120  steps.
# 0.9834300447730899
# Trial  366  converged in  1447  steps.
# 0.9168378862441665
# Trial  367  converged in  1294  steps.
# 0.8766730744027159
# Trial  368  converged in  1115  steps.
# 0.9692822306858586
# Trial  369  converged in  1240  steps.
# 1.167110522930575
# Trial  370  converged in  1749  steps.
# 0.47842177531337915
# Trial  371  converged in  535  steps.
# 1.0436208406453398
# Trial  372  converged in  1333  steps.
# 1.0896524414222537
# Trial  373  converged in  2163  steps.
# 0.6536335767900588
# Trial  374  converged in  755  steps.
# 0.8357847985159121
# Trial  375  converged in  1018  steps.
# 0.507235371690167
# Trial  376  converged in  369  steps.
# 1.0233245911135267
# Trial  377  converged in  1052  steps.
# 0.6282956951747166
# Trial  378  converged in  925  steps.
# 1.204218069378415
# Trial  379  converged in  2343  steps.
# 0.7111575803060985
# Trial  380  converged in  876  steps.
# 1.1765778080232288
# Trial  381  converged in  2030  steps.
# 0.959252754443892
# Trial  382  converged in  1018  steps.
# 0.8940885409767342
# Trial  383  converged in  1557  steps.
# 0.9007567083172066
# Trial  384  converged in  1643  steps.
# 0.9851295440869159
# Trial  385  converged in  1463  steps.
# 0.9633615305979439
# Trial  386  converged in  1172  steps.
# 1.2406660976920203
# Trial  387  converged in  2345  steps.
# 0.9095008970921622
# Trial  388  converged in  1391  steps.
# 0.7220970546912783
# Trial  389  converged in  978  steps.
# 0.5607903455113427
# Trial  390  converged in  628  steps.
# 0.8773370405496247
# Trial  391  converged in  1018  steps.
# 0.9750178587435204
# Trial  392  converged in  1413  steps.
# 1.1241792929751195
# Trial  393  converged in  2051  steps.
# 0.7258630117314712
# Trial  394  converged in  1151  steps.
# 0.6788160516224118
# Trial  395  converged in  941  steps.
# 0.8363442576407847
# Trial  396  converged in  1176  steps.
# 0.6806194379214445
# Trial  397  converged in  832  steps.
# 0.7131696200626515
# Trial  398  converged in  904  steps.
# 0.8650677368377844
# Trial  399  converged in  1351  steps.
# 0.8030581489608183
# Trial  400  converged in  1287  steps.
# 1.0087481585254676
# Trial  401  converged in  1518  steps.
# 0.7999701544970705
# Trial  402  converged in  1166  steps.
# 1.1313291979406683
# Trial  403  converged in  1705  steps.
# 0.7873240668500129
# Trial  404  converged in  1050  steps.
# 0.6760135509771321
# Trial  405  converged in  813  steps.
# 0.378104387034398
# Trial  406  converged in  394  steps.
# 0.728215379610239
# Trial  407  converged in  931  steps.
# 0.9706720131199247
# Trial  408  converged in  1406  steps.
# 0.505341190993554
# Trial  409  converged in  546  steps.
# 1.130053916385798
# Trial  410  converged in  1724  steps.
# 0.9937341267703533
# Trial  411  converged in  1285  steps.
# 0.8285730589485562
# Trial  412  converged in  1179  steps.
# 1.0332812018574686
# Trial  413  converged in  1650  steps.
# 1.0669743654407366
# Trial  414  converged in  1777  steps.
# 1.0142537641796499
# Trial  415  converged in  1825  steps.
# 0.7230480605709634
# Trial  416  converged in  835  steps.
# 0.5707462136053251
# Trial  417  converged in  471  steps.
# 0.8922242860944241
# Trial  418  converged in  1114  steps.
# 0.718698632873883
# Trial  419  converged in  853  steps.
# 0.5324704695370255
# Trial  420  converged in  514  steps.
# 0.9344076887021577
# Trial  421  converged in  1271  steps.
# 1.186831113576326
# Trial  422  converged in  1963  steps.
# 0.9463032759121555
# Trial  423  converged in  1314  steps.
# 0.7928737122002361
# Trial  424  converged in  1094  steps.
# 1.2638484895585371
# Trial  425  converged in  1383  steps.
# 0.9099748142022487
# Trial  426  converged in  1280  steps.
# 0.9652600677796358
# Trial  427  converged in  1615  steps.
# 0.8339243103479858
# Trial  428  converged in  1088  steps.
# 1.1278096765697296
# Trial  429  converged in  2043  steps.
# 0.673200098078578
# Trial  430  converged in  830  steps.
# 1.076757632267975
# Trial  431  converged in  1594  steps.
# 0.9842979688360435
# Trial  432  converged in  1644  steps.
# 0.9391982227693487
# Trial  433  converged in  1552  steps.
# 0.9667345666451879
# Trial  434  converged in  1455  steps.
# 1.239127892203531
# Trial  435  converged in  2345  steps.
# 0.7895108922711798
# Trial  436  converged in  998  steps.
# 1.0785895793266416
# Trial  437  converged in  1606  steps.
# 0.6214652704373936
# Trial  438  converged in  837  steps.
# 0.8538626284444518
# Trial  439  converged in  1251  steps.
# 0.8241601332549319
# Trial  440  converged in  1025  steps.
# 0.7126744852755035
# Trial  441  converged in  913  steps.
# 0.6393619233463722
# Trial  442  converged in  910  steps.
# 1.1640425090550122
# Trial  443  converged in  2011  steps.
# 1.230263540498114
# Trial  444  converged in  2264  steps.
# 0.7805946231519466
# Trial  445  converged in  1150  steps.
# 1.1806137087687971
# Trial  446  converged in  2067  steps.
# 1.0325308761236265
# Trial  447  converged in  1807  steps.
# 0.7014642575003208
# Trial  448  converged in  1068  steps.
# 0.9646374189795829
# Trial  449  converged in  1207  steps.
# 1.0480148526922697
# Trial  450  converged in  1410  steps.
# 0.8960729528830803
# Trial  451  converged in  780  steps.
# 1.0467495318479265
# Trial  452  converged in  1282  steps.
# 0.8265858510549434
# Trial  453  converged in  935  steps.
# 0.7218007993718414
# Trial  454  converged in  925  steps.
# 0.6407795054024885
# Trial  455  converged in  796  steps.
# 0.8483918156067142
# Trial  456  converged in  1498  steps.
# 0.8871139190851752
# Trial  457  converged in  1454  steps.
# 1.0271065028735322
# Trial  458  converged in  1894  steps.
# 0.999832101558944
# Trial  459  converged in  1960  steps.
# 0.6050054693541471
# Trial  460  converged in  913  steps.
# 0.5787627348572387
# Trial  461  converged in  440  steps.
# 0.8581432803731956
# Trial  462  converged in  1089  steps.
# 0.46117284507700834
# Trial  463  converged in  595  steps.
# 0.7899115154270636
# Trial  464  converged in  956  steps.
# 0.4272228282910896
# Trial  465  converged in  294  steps.
# 0.7310114021229025
# Trial  466  converged in  936  steps.
# 0.6906010660608267
# Trial  467  converged in  802  steps.
# 0.7721707382960099
# Trial  468  converged in  758  steps.
# 0.9778288195589843
# Trial  469  converged in  1429  steps.
# 0.8322828971938372
# Trial  470  converged in  856  steps.
# 1.043826356669639
# Trial  471  converged in  1772  steps.
# 0.8201600284394599
# Trial  472  converged in  1295  steps.
# 0.7122001281781424
# Trial  473  converged in  813  steps.
# 0.7510418861853652
# Trial  474  converged in  844  steps.
# 1.1283946216794984
# Trial  475  converged in  1500  steps.
# 0.7969860823969075
# Trial  476  converged in  1126  steps.
# 0.9358757196143737
# Trial  477  converged in  1332  steps.
# 0.5647208082345264
# Trial  478  converged in  684  steps.
# 0.8101566049787058
# Trial  479  converged in  923  steps.
# 0.7451530393683111
# Trial  480  converged in  696  steps.
# 0.7169264819054729
# Trial  481  converged in  804  steps.
# 1.02108842890361
# Trial  482  converged in  1694  steps.
# 0.972677166294797
# Trial  483  converged in  1572  steps.
# 1.1710693301754325
# Trial  484  converged in  2159  steps.
# 1.101013079998638
# Trial  485  converged in  1772  steps.
# 1.4143330588856047
# Trial  486  converged in  2443  steps.
# 0.7913818596960609
# Trial  487  converged in  1158  steps.
# 0.9760683557166183
# Trial  488  converged in  1448  steps.
# 0.9108310257400992
# Trial  489  converged in  1540  steps.
# 0.29293759827803884
# Trial  490  converged in  236  steps.
# 1.0692898335795535
# Trial  491  converged in  1885  steps.
# 1.2304853524716297
# Trial  492  converged in  2140  steps.
# 1.1827072627202115
# Trial  493  converged in  2126  steps.
# 0.8733593633239143
# Trial  494  converged in  1317  steps.
# 1.1977933235042024
# Trial  495  converged in  2167  steps.
# 0.8948795627072372
# Trial  496  converged in  1394  steps.
# 0.9710027199389331
# Trial  497  converged in  1489  steps.
# 0.741158511759628
# Trial  498  converged in  963  steps.
# 0.9238756060914468
# Trial  499  converged in  1162  steps.
# 1.1761466915325305
# Trial  500  converged in  2133  steps.
# 0.8604475618125961
# Trial  501  converged in  1143  steps.
# 0.8666037259881136
# Trial  502  converged in  1180  steps.
# 0.7499564093157377
# Trial  503  converged in  1123  steps.
# 1.2957743132113821
# Trial  504  converged in  2846  steps.
# 1.068986329153875
# Trial  505  converged in  1848  steps.
# 0.4158144552443538
# Trial  506  converged in  455  steps.
# 1.1099369216791686
# Trial  507  converged in  1289  steps.
# 0.5984399130411671
# Trial  508  converged in  643  steps.
# 0.9409574442854349
# Trial  509  converged in  1586  steps.
# 0.9892773039324612
# Trial  510  converged in  1641  steps.
# 1.1241207888658014
# Trial  511  converged in  1778  steps.
# 0.8030653509301356
# Trial  512  converged in  1284  steps.
# 0.9569170687673094
# Trial  513  converged in  1677  steps.
# 0.9611871427176487
# Trial  514  converged in  1064  steps.
# 0.8300088428219129
# Trial  515  converged in  1066  steps.
# 1.4209305856917211
# Trial  516  converged in  2457  steps.
# 0.9089992127178661
# Trial  517  converged in  1398  steps.
# 0.7839685813618636
# Trial  518  converged in  1023  steps.
# 0.422916218780576
# Trial  519  converged in  320  steps.
# 1.1068019323164662
# Trial  520  converged in  1969  steps.
# 0.7155851574426836
# Trial  521  converged in  775  steps.
# 1.0271071236033917
# Trial  522  converged in  1516  steps.
# 1.0476433652858992
# Trial  523  converged in  1585  steps.
# 1.3619607456171852
# Trial  524  converged in  2664  steps.
# 0.667274458567124
# Trial  525  converged in  860  steps.
# 1.0431066826190862
# Trial  526  converged in  1590  steps.
# 0.9348390067905787
# Trial  527  converged in  1501  steps.
# 0.7579679146314863
# Trial  528  converged in  1082  steps.
# 0.34459143008606963
# Trial  529  converged in  255  steps.
# 0.8322331850730035
# Trial  530  converged in  1086  steps.
# 0.8289999576725686
# Trial  531  converged in  1090  steps.
# 0.7239199919050195
# Trial  532  converged in  970  steps.
# 1.0705380045027117
# Trial  533  converged in  1848  steps.
# 0.8692463484809768
# Trial  534  converged in  1079  steps.
# 1.023027299317664
# Trial  535  converged in  1548  steps.
# 1.1943913550363534
# Trial  536  converged in  2321  steps.
# 0.740576521994465
# Trial  537  converged in  725  steps.
# 1.141243748429437
# Trial  538  converged in  1753  steps.
# 1.3082814007647177
# Trial  539  converged in  1854  steps.
# 1.0459776297893388
# Trial  540  converged in  1829  steps.
# 0.7978940605778229
# Trial  541  converged in  1235  steps.
# 0.9214096698776835
# Trial  542  converged in  1525  steps.
# 0.42343136789393965
# Trial  543  converged in  652  steps.
# 0.9214263260853096
# Trial  544  converged in  1509  steps.
# 1.0851516754843393
# Trial  545  converged in  1791  steps.
# 1.3503477043936452
# Trial  546  converged in  2208  steps.
# 0.431871137505826
# Trial  547  converged in  470  steps.
# 1.1412769312113547
# Trial  548  converged in  1903  steps.
# 0.8407960385661224
# Trial  549  converged in  1321  steps.
# 0.684263152186501
# Trial  550  converged in  770  steps.
# 1.0825803081678902
# Trial  551  converged in  1741  steps.
# 1.0318769649002424
# Trial  552  converged in  1266  steps.
# 0.9006837868445631
# Trial  553  converged in  1323  steps.
# 0.6694975452017978
# Trial  554  converged in  688  steps.
# 0.8986249196526265
# Trial  555  converged in  1298  steps.
# 0.5585651596676446
# Trial  556  converged in  558  steps.
# 0.9678832650928082
# Trial  557  converged in  1473  steps.
# 0.8810713555007014
# Trial  558  converged in  977  steps.
# 0.6877541511684654
# Trial  559  converged in  779  steps.
# 0.6530918815326271
# Trial  560  converged in  659  steps.
# 0.5389375082551277
# Trial  561  converged in  502  steps.
# 0.6214866192592039
# Trial  562  converged in  796  steps.
# 0.7410260836525482
# Trial  563  converged in  1053  steps.
# 1.005778445452248
# Trial  564  converged in  1302  steps.
# 1.050524173568636
# Trial  565  converged in  1485  steps.
# 0.7399993451321886
# Trial  566  converged in  738  steps.
# 1.3049191696135438
# Trial  567  converged in  1839  steps.
# 1.179876447751631
# Trial  568  converged in  1514  steps.
# 0.8328404486221153
# Trial  569  converged in  1209  steps.
# 1.1357248509210434
# Trial  570  converged in  1967  steps.
# 1.0115290352209918
# Trial  571  converged in  1435  steps.
# 1.0958446092860077
# Trial  572  converged in  1753  steps.
# 0.8015364345156397
# Trial  573  converged in  1158  steps.
# 0.8609705749770903
# Trial  574  converged in  1229  steps.
# 0.9227563815809077
# Trial  575  converged in  1241  steps.
# 0.3799060041744296
# Trial  576  converged in  350  steps.
# 1.1394223354504451
# Trial  577  converged in  1756  steps.
# 0.7232039849580724
# Trial  578  converged in  942  steps.
# 0.6466064752791857
# Trial  579  converged in  816  steps.
# 1.1164505331853944
# Trial  580  converged in  1889  steps.
# 0.6835840694313525
# Trial  581  converged in  877  steps.
# 0.985768957696257
# Trial  582  converged in  1444  steps.
# 0.8993203964914246
# Trial  583  converged in  1446  steps.
# 1.5120684643767828
# Trial  584  converged in  3182  steps.
# 0.637131691328258
# Trial  585  converged in  852  steps.
# 0.9805033936213254
# Trial  586  converged in  1571  steps.
# 0.8519440085164739
# Trial  587  converged in  1292  steps.
# 0.21901190185799038
# Trial  588  converged in  164  steps.
# 1.2230913219223358
# Trial  589  converged in  3483  steps.
# 0.8469475982333003
# Trial  590  converged in  1191  steps.
# 0.8140846863282127
# Trial  591  converged in  810  steps.
# 1.1342070924513474
# Trial  592  converged in  1815  steps.
# 0.7689598853206813
# Trial  593  converged in  987  steps.
# 0.8700567836472501
# Trial  594  converged in  1236  steps.
# 0.9932553974372792
# Trial  595  converged in  1569  steps.
# 0.6332077589355029
# Trial  596  converged in  764  steps.
# 0.7956389824510316
# Trial  597  converged in  1372  steps.
# 0.38799085713955694
# Trial  598  converged in  691  steps.
# 0.822378840068997
# Trial  599  converged in  1065  steps.
# 0.8392129937998016
# Trial  600  converged in  1147  steps.
# 0.76468262757847
# Trial  601  converged in  842  steps.
# 0.6108882789594126
# Trial  602  converged in  676  steps.
# 1.0035766637816452
# Trial  603  converged in  1626  steps.
# 1.1817534321045704
# Trial  604  converged in  2271  steps.
# 1.0296848237815615
# Trial  605  converged in  1466  steps.
# 0.8118066260172921
# Trial  606  converged in  410  steps.
# 0.7002362488108029
# Trial  607  converged in  995  steps.
# 1.0594082803076956
# Trial  608  converged in  1625  steps.
# 0.6557450940330427
# Trial  609  converged in  844  steps.
# 0.82725350241998
# Trial  610  converged in  1288  steps.
# 0.8878301616723883
# Trial  611  converged in  1210  steps.
# 0.8121539514024041
# Trial  612  converged in  1026  steps.
# 0.9384039748191954
# Trial  613  converged in  1302  steps.
# 0.8425914716950718
# Trial  614  converged in  1297  steps.
# 1.0902397881050159
# Trial  615  converged in  1828  steps.
# 0.7762289719514752
# Trial  616  converged in  1054  steps.
# 1.084856918663126
# Trial  617  converged in  1548  steps.
# 0.8096471444147645
# Trial  618  converged in  1153  steps.
# 0.5137472008944919
# Trial  619  converged in  559  steps.
# 1.2361930728358497
# Trial  620  converged in  2428  steps.
# 0.7713833427064407
# Trial  621  converged in  1182  steps.
# 0.6666455531439415
# Trial  622  converged in  838  steps.
# 0.7216963465857886
# Trial  623  converged in  560  steps.
# 0.6538267954979571
# Trial  624  converged in  644  steps.
# 0.599923536098215
# Trial  625  converged in  649  steps.
# 0.6256058746347123
# Trial  626  converged in  896  steps.
# 0.7555098899732896
# Trial  627  converged in  972  steps.
# 1.176480205453108
# Trial  628  converged in  1893  steps.
# 1.2211754947313536
# Trial  629  converged in  2237  steps.
# 0.8987731643204162
# Trial  630  converged in  1176  steps.
# 1.1207426324501182
# Trial  631  converged in  1883  steps.
# 0.9395286161727009
# Trial  632  converged in  1182  steps.
# 0.46796062451692566
# Trial  633  converged in  416  steps.
# 0.6531478936808208
# Trial  634  converged in  571  steps.
# 0.7441981149097133
# Trial  635  converged in  807  steps.
# 0.8417399417283858
# Trial  636  converged in  1171  steps.
# 0.8360226560002523
# Trial  637  converged in  988  steps.
# 1.3109850261817761
# Trial  638  converged in  2779  steps.
# 0.9878485133429689
# Trial  639  converged in  1702  steps.
# 1.1139541906979913
# Trial  640  converged in  1567  steps.
# 1.0077658986374538
# Trial  641  converged in  1722  steps.
# 1.1706691599980081
# Trial  642  converged in  2056  steps.
# 0.8278732974764409
# Trial  643  converged in  1299  steps.
# 0.949257787585601
# Trial  644  converged in  908  steps.
# 0.9301809073936952
# Trial  645  converged in  1640  steps.
# 0.5214252432039133
# Trial  646  converged in  515  steps.
# 0.850981091239207
# Trial  647  converged in  1148  steps.
# 0.7538298082265027
# Trial  648  converged in  925  steps.
# 0.4345088186937491
# Trial  649  converged in  330  steps.
# 0.8233147046347559
# Trial  650  converged in  995  steps.
# 0.6753682455263353
# Trial  651  converged in  820  steps.
# 1.0847875770149324
# Trial  652  converged in  1674  steps.
# 1.1162527594047096
# Trial  653  converged in  1968  steps.
# 1.1194107323529092
# Trial  654  converged in  2222  steps.
# 1.2631161340535122
# Trial  655  converged in  2575  steps.
# 0.7471215090469779
# Trial  656  converged in  1024  steps.
# 0.8910673996375439
# Trial  657  converged in  1531  steps.
# 1.0970215988362737
# Trial  658  converged in  1425  steps.
# 0.7937604624885661
# Trial  659  converged in  1035  steps.
# 1.064451692004968
# Trial  660  converged in  1385  steps.
# 0.911550518966946
# Trial  661  converged in  1366  steps.
# 0.8626398613091681
# Trial  662  converged in  1064  steps.
# 0.6155088226060453
# Trial  663  converged in  815  steps.
# 0.9495960088930844
# Trial  664  converged in  1155  steps.
# 0.7489216194771063
# Trial  665  converged in  791  steps.
# 0.8338122008709696
# Trial  666  converged in  1208  steps.
# 0.8222660412938213
# Trial  667  converged in  1119  steps.
# 0.5664881436893326
# Trial  668  converged in  677  steps.
# 0.811417319835285
# Trial  669  converged in  1156  steps.
# 0.46193982862043875
# Trial  670  converged in  438  steps.
# 0.728966675653866
# Trial  671  converged in  903  steps.
# 1.1214165051701006
# Trial  672  converged in  1941  steps.
# 0.8018758595803783
# Trial  673  converged in  887  steps.
# 0.9502089568862258
# Trial  674  converged in  1098  steps.
# 1.2178620280563357
# Trial  675  converged in  1477  steps.
# 0.8254448791740584
# Trial  676  converged in  1186  steps.
# 1.0436052528475004
# Trial  677  converged in  1406  steps.
# 0.9622596951232547
# Trial  678  converged in  1580  steps.
# 0.873499249722574
# Trial  679  converged in  1294  steps.
# 1.1449312162242296
# Trial  680  converged in  643  steps.
# 1.1769500010373963
# Trial  681  converged in  2340  steps.
# 0.7089728228776452
# Trial  682  converged in  955  steps.
# 1.0042370353722094
# Trial  683  converged in  1637  steps.
# 0.9003886798281211
# Trial  684  converged in  1429  steps.
# 0.7802410953793727
# Trial  685  converged in  803  steps.
# 0.8390656930066639
# Trial  686  converged in  497  steps.
# 0.9911131542904166
# Trial  687  converged in  1400  steps.
# 1.1778445060252825
# Trial  688  converged in  1768  steps.
# 1.0077129579590733
# Trial  689  converged in  1694  steps.
# 0.6008264437946154
# Trial  690  converged in  740  steps.
# 1.1636579189032388
# Trial  691  converged in  900  steps.
# 0.939175036223513
# Trial  692  converged in  1622  steps.
# 0.807931982815625
# Trial  693  converged in  1161  steps.
# 1.1177769042620838
# Trial  694  converged in  1883  steps.
# 1.0193174859449838
# Trial  695  converged in  1129  steps.
# 0.8816206638074939
# Trial  696  converged in  967  steps.
# 1.1749765805314416
# Trial  697  converged in  2078  steps.
# 1.076993728087809
# Trial  698  converged in  1613  steps.
# 1.1146952589799308
# Trial  699  converged in  1912  steps.
# 0.894082357678636
# Trial  700  converged in  1224  steps.
# 0.8238384407083214
# Trial  701  converged in  1122  steps.
# 0.899161447750893
# Trial  702  converged in  374  steps.
# 0.6380292929297493
# Trial  703  converged in  662  steps.
# 1.0884621441136928
# Trial  704  converged in  1348  steps.
# 1.2242291726438963
# Trial  705  converged in  2213  steps.
# 1.0500328863730057
# Trial  706  converged in  1919  steps.
# 0.9226516459750298
# Trial  707  converged in  1430  steps.
# 1.147166408820627
# Trial  708  converged in  1738  steps.
# 0.719672260575976
# Trial  709  converged in  839  steps.
# 0.5561137229327817
# Trial  710  converged in  755  steps.
# 0.8122369287479968
# Trial  711  converged in  803  steps.
# 1.1187992890656746
# Trial  712  converged in  2174  steps.
# 1.0755399825540575
# Trial  713  converged in  1373  steps.
# 0.5996026459458242
# Trial  714  converged in  788  steps.
# 1.1484560394176142
# Trial  715  converged in  1879  steps.
# 0.783498010509659
# Trial  716  converged in  1205  steps.
# 1.2365757979326573
# Trial  717  converged in  2254  steps.
# 0.6637095659420486
# Trial  718  converged in  756  steps.
# 0.4010608383046179
# Trial  719  converged in  382  steps.
# 0.9367063774474749
# Trial  720  converged in  1456  steps.
# 1.5041683857221784
# Trial  721  converged in  3623  steps.
# 0.7300360303260595
# Trial  722  converged in  716  steps.
# 0.7432979579881057
# Trial  723  converged in  801  steps.
# 0.45541231219378503
# Trial  724  converged in  423  steps.
# 1.1100271145172658
# Trial  725  converged in  1179  steps.
# 0.929913328794294
# Trial  726  converged in  1353  steps.
# 0.7008753961141908
# Trial  727  converged in  965  steps.
# 0.7214040446976666
# Trial  728  converged in  402  steps.
# 0.688658670337503
# Trial  729  converged in  1012  steps.
# 1.2910963340008534
# Trial  730  converged in  2044  steps.
# 0.645811585609539
# Trial  731  converged in  871  steps.
# 0.7643861491710263
# Trial  732  converged in  760  steps.
# 0.69967023978307
# Trial  733  converged in  531  steps.
# 0.7995885803850147
# Trial  734  converged in  1025  steps.
# 1.2336801487637097
# Trial  735  converged in  1787  steps.
# 0.8591392549970018
# Trial  736  converged in  636  steps.
# 0.7828921181050806
# Trial  737  converged in  912  steps.
# 0.706842188596122
# Trial  738  converged in  763  steps.
# 0.6027101592480817
# Trial  739  converged in  558  steps.
# 0.6375322084907908
# Trial  740  converged in  700  steps.
# 0.9089233605629744
# Trial  741  converged in  1341  steps.
# 0.5888040669882388
# Trial  742  converged in  734  steps.
# 0.9603680671258213
# Trial  743  converged in  1456  steps.
# 1.109064357784586
# Trial  744  converged in  1785  steps.
# 0.8173501241950606
# Trial  745  converged in  1244  steps.
# 0.47896866114960684
# Trial  746  converged in  626  steps.
# 1.0008202446923962
# Trial  747  converged in  1629  steps.
# 1.2398616344871771
# Trial  748  converged in  2089  steps.
# 0.9655710836999243
# Trial  749  converged in  1510  steps.
# 1.1776819171283586
# Trial  750  converged in  2072  steps.
# 0.7356234163438731
# Trial  751  converged in  965  steps.
# 0.9117162013966641
# Trial  752  converged in  1565  steps.
# 1.2287294037467695
# Trial  753  converged in  2484  steps.
# 1.1598620539346485
# Trial  754  converged in  2036  steps.
# 0.7038281863772691
# Trial  755  converged in  428  steps.
# 0.9043665756579261
# Trial  756  converged in  1512  steps.
# 0.8490194126562004
# Trial  757  converged in  1468  steps.
# 0.4872546813115958
# Trial  758  converged in  487  steps.
# 0.686704773378741
# Trial  759  converged in  749  steps.
# 0.46620399743748214
# Trial  760  converged in  497  steps.
# 0.5938260036660509
# Trial  761  converged in  657  steps.
# 1.129946736144884
# Trial  762  converged in  1774  steps.
# 1.0176765823493745
# Trial  763  converged in  1402  steps.
# 0.6860404713303875
# Trial  764  converged in  623  steps.
# 0.7852071788212531
# Trial  765  converged in  1040  steps.
# 0.9661078363807499
# Trial  766  converged in  1402  steps.
# 1.041723576783711
# Trial  767  converged in  1536  steps.
# 0.7261943558920768
# Trial  768  converged in  567  steps.
# 0.8790174416604681
# Trial  769  converged in  1117  steps.
# 0.842395530908664
# Trial  770  converged in  1018  steps.
# 0.8977692228840916
# Trial  771  converged in  1269  steps.
# 0.9009910957910279
# Trial  772  converged in  1454  steps.
# 0.7049689267746703
# Trial  773  converged in  1194  steps.
# 0.9779432995664293
# Trial  774  converged in  1617  steps.
# 0.9584503441493359
# Trial  775  converged in  1206  steps.
# 1.2206059977408281
# Trial  776  converged in  960  steps.
# 0.5640653379509897
# Trial  777  converged in  635  steps.
# 0.6034717987799885
# Trial  778  converged in  611  steps.
# 0.7313200315949439
# Trial  779  converged in  688  steps.
# 0.8442418935161377
# Trial  780  converged in  1233  steps.
# 0.9455081058250309
# Trial  781  converged in  1387  steps.
# 0.8087129648500027
# Trial  782  converged in  951  steps.
# 0.9457492954625131
# Trial  783  converged in  1459  steps.
# 0.4485235579273695
# Trial  784  converged in  520  steps.
# 0.8238300702687402
# Trial  785  converged in  995  steps.
# 1.0199385588470498
# Trial  786  converged in  1147  steps.
# 0.6253400588836568
# Trial  787  converged in  671  steps.
# 0.6577905433459683
# Trial  788  converged in  737  steps.
# 0.7603880458181768
# Trial  789  converged in  1039  steps.
# 0.5565458587750934
# Trial  790  converged in  609  steps.
# 0.5270690243190285
# Trial  791  converged in  534  steps.
# 1.3332677660013073
# Trial  792  converged in  2004  steps.
# 0.9783257644040074
# Trial  793  converged in  1475  steps.
# 0.814298535383553
# Trial  794  converged in  1073  steps.
# 1.194616534017123
# Trial  795  converged in  1911  steps.
# 0.7992676893682132
# Trial  796  converged in  889  steps.
# 0.8814521171822598
# Trial  797  converged in  1210  steps.
# 1.274894556510919
# Trial  798  converged in  1505  steps.
# 0.6904250501526636
# Trial  799  converged in  1025  steps.
# 0.7808771369328434
# Trial  800  converged in  889  steps.
# 0.7902703614773797
# Trial  801  converged in  1119  steps.
# 1.2163168677325182
# Trial  802  converged in  2348  steps.
# 1.3698566904035376
# Trial  803  converged in  2402  steps.
# 1.2774723869594338
# Trial  804  converged in  1660  steps.
# 0.846102092389037
# Trial  805  converged in  1151  steps.
# 1.0295938603171397
# Trial  806  converged in  1360  steps.
# 1.0179566147165304
# Trial  807  converged in  1500  steps.
# 0.6218090296409613
# Trial  808  converged in  743  steps.
# 1.5382771588465156
# Trial  809  converged in  3908  steps.
# 0.8678158594600598
# Trial  810  converged in  1557  steps.
# 1.1568132483323341
# Trial  811  converged in  1180  steps.
# 0.4499027209834732
# Trial  812  converged in  401  steps.
# 1.1406799597682793
# Trial  813  converged in  1760  steps.
# 1.001943857281556
# Trial  814  converged in  1650  steps.
# 0.8299471272741342
# Trial  815  converged in  1264  steps.
# 0.7696427999404942
# Trial  816  converged in  629  steps.
# 0.8210813510883355
# Trial  817  converged in  1046  steps.
# 0.9021403090692587
# Trial  818  converged in  1418  steps.
# 0.7666595902747304
# Trial  819  converged in  1001  steps.
# 1.2682998165928039
# Trial  820  converged in  2183  steps.
# 0.7939064396878244
# Trial  821  converged in  831  steps.
# 0.8989825008966046
# Trial  822  converged in  1215  steps.
# 0.841455034611594
# Trial  823  converged in  736  steps.
# 0.7683672763849393
# Trial  824  converged in  1079  steps.
# 0.8697086732444312
# Trial  825  converged in  1435  steps.
# 0.8239783092480265
# Trial  826  converged in  603  steps.
# 1.1852867236238323
# Trial  827  converged in  2017  steps.
# 1.0183112562869063
# Trial  828  converged in  1636  steps.
# 0.930344878352761
# Trial  829  converged in  1560  steps.
# 0.6863211451475071
# Trial  830  converged in  966  steps.
# 1.202721219014242
# Trial  831  converged in  2239  steps.
# 0.708886724113458
# Trial  832  converged in  1046  steps.
# 0.6364088157471993
# Trial  833  converged in  775  steps.
# 0.9569781124275635
# Trial  834  converged in  1029  steps.
# 0.6129410246677496
# Trial  835  converged in  584  steps.
# 0.9531176991036503
# Trial  836  converged in  1597  steps.
# 0.6083368404320083
# ...
# 0.7695453546589791
# Trial  9728  converged in  1021  steps.
# 1.1691172637019107
# Trial  9729  converged in  1833  steps.
# 1.3183378921186435
# Trial  9730  converged in  2417  steps.
# 0.6166598963191765
# Trial  9731  converged in  933  steps.
# 0.640010282157208
# Trial  9732  converged in  568  steps.
# 0.7221523271010274
# Trial  9733  converged in  812  steps.
# 0.6219325954560522
# Trial  9734  converged in  689  steps.
# 0.937455030050571
# Trial  9735  converged in  1287  steps.
# 0.7713861225249218
# Trial  9736  converged in  1056  steps.
# 0.9726542496543014
# Trial  9737  converged in  1496  steps.
# 0.5102557420050395
# Trial  9738  converged in  508  steps.
# 0.9274492700304665
# Trial  9739  converged in  1164  steps.
# 0.9327222333968564
# Trial  9740  converged in  1356  steps.
# 1.0816412065560121
# Trial  9741  converged in  1438  steps.
# 0.9868889560592748
# Trial  9742  converged in  1379  steps.
# 0.9087387417312572
# Trial  9743  converged in  1499  steps.
# 1.008186349758291
# Trial  9744  converged in  1757  steps.
# 1.2546517120460037
# Trial  9745  converged in  2086  steps.
# 1.1684103189528237
# Trial  9746  converged in  1953  steps.
# 0.3839161881360114
# Trial  9747  converged in  431  steps.
# 0.47427991298925715
# Trial  9748  converged in  487  steps.
# 1.2910671271678242
# Trial  9749  converged in  2705  steps.
# 0.8001907800765262
# Trial  9750  converged in  1356  steps.
# 1.305998475765896
# Trial  9751  converged in  2475  steps.
# 1.4714199912546577
# Trial  9752  converged in  3181  steps.
# 0.7389971924067964
# Trial  9753  converged in  567  steps.
# 0.8702733674798502
# Trial  9754  converged in  1375  steps.
# 1.0680259913152514
# Trial  9755  converged in  1872  steps.
# 0.717714489291623
# Trial  9756  converged in  932  steps.
# 0.6818748781685109
# Trial  9757  converged in  1033  steps.
# 0.678975688413351
# Trial  9758  converged in  991  steps.
# 0.9196862898550779
# Trial  9759  converged in  1220  steps.
# 1.0595808579500623
# Trial  9760  converged in  997  steps.
# 0.41698664038720634
# Trial  9761  converged in  594  steps.
# 0.9647527898341265
# Trial  9762  converged in  1823  steps.
# 0.9880050067726881
# Trial  9763  converged in  1686  steps.
# 0.9142909955909342
# Trial  9764  converged in  1400  steps.
# 0.8476152877430941
# Trial  9765  converged in  871  steps.
# 1.1574788193830292
# Trial  9766  converged in  1808  steps.
# 0.684332447607201
# Trial  9767  converged in  858  steps.
# 0.6333325218532243
# Trial  9768  converged in  725  steps.
# 1.030546916164979
# Trial  9769  converged in  1606  steps.
# 0.7769116373881778
# Trial  9770  converged in  1156  steps.
# 1.1735631042911523
# Trial  9771  converged in  2493  steps.
# 1.0562659613029097
# Trial  9772  converged in  2148  steps.
# 0.7376053636220075
# Trial  9773  converged in  947  steps.
# 0.40589552818418434
# Trial  9774  converged in  211  steps.
# 0.9082216908456456
# Trial  9775  converged in  1028  steps.
# 0.8612228491770637
# Trial  9776  converged in  1026  steps.
# 0.741130097732035
# Trial  9777  converged in  1116  steps.
# 1.0726485091085705
# Trial  9778  converged in  1686  steps.
# 0.5988705257767075
# Trial  9779  converged in  605  steps.
# 1.0931517676705764
# Trial  9780  converged in  1440  steps.
# 1.114708692290773
# Trial  9781  converged in  2013  steps.
# 1.0382699086953053
# Trial  9782  converged in  1657  steps.
# 0.8145574460199486
# Trial  9783  converged in  777  steps.
# 0.7563049511395407
# Trial  9784  converged in  876  steps.
# 1.1753313717703062
# Trial  9785  converged in  1594  steps.
# 1.278788344955489
# Trial  9786  converged in  2517  steps.
# 1.1307857292930998
# Trial  9787  converged in  2204  steps.
# 0.6940356922617247
# Trial  9788  converged in  790  steps.
# 1.326650371415031
# Trial  9789  converged in  2042  steps.
# 0.7582147546194926
# Trial  9790  converged in  955  steps.
# 0.8436129539062863
# Trial  9791  converged in  830  steps.
# 0.5108973357983633
# Trial  9792  converged in  516  steps.
# 0.4002408887994909
# Trial  9793  converged in  370  steps.
# 0.6759771181660158
# Trial  9794  converged in  809  steps.
# 0.7697791475813042
# Trial  9795  converged in  930  steps.
# 1.176856373668963
# Trial  9796  converged in  1671  steps.
# 0.8868011119694079
# Trial  9797  converged in  1370  steps.
# 0.8054893353248193
# Trial  9798  converged in  1035  steps.
# 0.796109091465472
# Trial  9799  converged in  824  steps.
# 0.6952450028382213
# Trial  9800  converged in  735  steps.
# 0.5502404885802071
# Trial  9801  converged in  570  steps.
# 0.47644779629307804
# Trial  9802  converged in  540  steps.
# 0.9597998687806383
# Trial  9803  converged in  735  steps.
# 0.9603370649918576
# Trial  9804  converged in  1534  steps.
# 0.8682965942258519
# Trial  9805  converged in  1220  steps.
# 0.9680993881098585
# Trial  9806  converged in  1372  steps.
# 0.9619362844631513
# Trial  9807  converged in  1641  steps.
# 0.5733310493614459
# Trial  9808  converged in  804  steps.
# 0.7206854898550342
# Trial  9809  converged in  977  steps.
# 1.2676420146490501
# Trial  9810  converged in  1472  steps.
# 0.7200270544254996
# Trial  9811  converged in  982  steps.
# 1.135712968958503
# Trial  9812  converged in  1787  steps.
# 1.0651607467717743
# Trial  9813  converged in  1637  steps.
# 1.3518085116461782
# Trial  9814  converged in  1841  steps.
# 0.9676972103254932
# Trial  9815  converged in  1293  steps.
# 0.6585962280731105
# Trial  9816  converged in  770  steps.
# 0.948535532178261
# Trial  9817  converged in  1240  steps.
# 0.6557901322075164
# Trial  9818  converged in  659  steps.
# 1.2967381527862196
# Trial  9819  converged in  1594  steps.
# 0.40848439315372476
# Trial  9820  converged in  429  steps.
# 0.7008660027064483
# Trial  9821  converged in  613  steps.
# 0.8391408410428245
# Trial  9822  converged in  1024  steps.
# 0.7198746003549659
# Trial  9823  converged in  991  steps.
# 0.6799387908535033
# Trial  9824  converged in  913  steps.
# 0.924903229248444
# Trial  9825  converged in  991  steps.
# 0.8882378893436691
# Trial  9826  converged in  1230  steps.
# 1.195350098503299
# Trial  9827  converged in  1989  steps.
# 0.7797988492049965
# Trial  9828  converged in  1061  steps.
# 0.7361681839243815
# Trial  9829  converged in  828  steps.
# 1.0056582290521416
# Trial  9830  converged in  996  steps.
# 0.9357788503304474
# Trial  9831  converged in  1006  steps.
# 1.1258280265504828
# Trial  9832  converged in  1264  steps.
# 1.0484818787972319
# Trial  9833  converged in  1727  steps.
# 0.9022277943635237
# Trial  9834  converged in  1465  steps.
# 0.741203197021364
# Trial  9835  converged in  1184  steps.
# 0.9265434174044197
# Trial  9836  converged in  1574  steps.
# 0.7966582519136078
# Trial  9837  converged in  1062  steps.
# 0.7881135316374529
# Trial  9838  converged in  1022  steps.
# 0.7251904520067376
# Trial  9839  converged in  951  steps.
# 0.8457040185362522
# Trial  9840  converged in  811  steps.
# 0.7475754499389107
# Trial  9841  converged in  1135  steps.
# 0.7733427964918094
# Trial  9842  converged in  1046  steps.
# 0.3719386970980407
# Trial  9843  converged in  366  steps.
# 0.9393066829552813
# Trial  9844  converged in  1484  steps.
# 0.8594317823552838
# Trial  9845  converged in  1234  steps.
# 1.1269970124571056
# Trial  9846  converged in  1926  steps.
# 1.0117677600171335
# Trial  9847  converged in  1319  steps.
# 0.6998624766595529
# Trial  9848  converged in  479  steps.
# 1.0140723327942711
# Trial  9849  converged in  1547  steps.
# 0.6731638032497772
# Trial  9850  converged in  687  steps.
# 1.1782867208852863
# Trial  9851  converged in  1975  steps.
# 0.5656508295191933
# Trial  9852  converged in  682  steps.
# 0.8946342140450845
# Trial  9853  converged in  1087  steps.
# 0.8859265436537358
# Trial  9854  converged in  1415  steps.
# 0.7085038444971727
# Trial  9855  converged in  729  steps.
# 0.5495428022123904
# Trial  9856  converged in  961  steps.
# 0.7808856541157956
# Trial  9857  converged in  1293  steps.
# 0.9313166533002384
# Trial  9858  converged in  1091  steps.
# 1.2689910888136264
# Trial  9859  converged in  1438  steps.
# 0.5323856497718982
# Trial  9860  converged in  615  steps.
# 0.46576591688117475
# Trial  9861  converged in  281  steps.
# 0.9533154541483175
# Trial  9862  converged in  1404  steps.
# 0.5797520715760578
# Trial  9863  converged in  637  steps.
# 1.1830589814697094
# Trial  9864  converged in  1828  steps.
# 0.7132344788415889
# Trial  9865  converged in  953  steps.
# 0.7165069198140129
# Trial  9866  converged in  988  steps.
# 0.9007229395170975
# Trial  9867  converged in  1196  steps.
# 0.9792815129744494
# Trial  9868  converged in  1514  steps.
# 0.7112292137822395
# Trial  9869  converged in  887  steps.
# 0.780855582112322
# Trial  9870  converged in  908  steps.
# 1.179473518390941
# Trial  9871  converged in  1859  steps.
# 0.8204779538429521
# Trial  9872  converged in  1099  steps.
# 0.3982018561008882
# Trial  9873  converged in  321  steps.
# 1.174589257511433
# Trial  9874  converged in  1918  steps.
# 0.9214556889236579
# Trial  9875  converged in  1131  steps.
# 0.9335519426137254
# Trial  9876  converged in  1161  steps.
# 0.6959940595680798
# Trial  9877  converged in  786  steps.
# 1.1984926811636902
# Trial  9878  converged in  1748  steps.
# 0.9132998717459948
# Trial  9879  converged in  1354  steps.
# 1.5106337386021722
# Trial  9880  converged in  3007  steps.
# 1.017254096735049
# Trial  9881  converged in  1509  steps.
# 0.909077595995607
# Trial  9882  converged in  1084  steps.
# 0.788310462343973
# Trial  9883  converged in  1041  steps.
# 0.7150920863190053
# Trial  9884  converged in  707  steps.
# 0.8045376986767612
# Trial  9885  converged in  1254  steps.
# 0.926157852755123
# Trial  9886  converged in  1400  steps.
# 0.9495199259674907
# Trial  9887  converged in  1044  steps.
# 0.9840026079018266
# Trial  9888  converged in  1475  steps.
# 0.9047546357948548
# Trial  9889  converged in  1083  steps.
# 0.7878668298243726
# Trial  9890  converged in  773  steps.
# 0.9348956278799461
# Trial  9891  converged in  1398  steps.
# 0.7705938245097177
# Trial  9892  converged in  1272  steps.
# 0.683783269454696
# Trial  9893  converged in  802  steps.
# 0.8775499034800248
# Trial  9894  converged in  1153  steps.
# 0.9031273896808892
# Trial  9895  converged in  1323  steps.
# 1.0508825774676245
# Trial  9896  converged in  1821  steps.
# 0.8343769311404918
# Trial  9897  converged in  854  steps.
# 1.0544405294557384
# Trial  9898  converged in  1873  steps.
# 0.6345401019573145
# Trial  9899  converged in  714  steps.
# 0.738862853854599
# Trial  9900  converged in  636  steps.
# 1.0882861470591683
# Trial  9901  converged in  1976  steps.
# 1.1491060145707366
# Trial  9902  converged in  1743  steps.
# 0.8105495857767102
# Trial  9903  converged in  1026  steps.
# 0.7838779846026579
# Trial  9904  converged in  1099  steps.
# 0.9311326815798089
# Trial  9905  converged in  1389  steps.
# 0.8988944070378118
# Trial  9906  converged in  1210  steps.
# 1.2267073107512871
# Trial  9907  converged in  2110  steps.
# 0.6903621957404898
# Trial  9908  converged in  855  steps.
# 0.781294019976819
# Trial  9909  converged in  1127  steps.
# 1.0605939988147366
# Trial  9910  converged in  1663  steps.
# 1.1483144543475512
# Trial  9911  converged in  1327  steps.
# 1.265695261320743
# Trial  9912  converged in  2291  steps.
# 0.695671845974577
# Trial  9913  converged in  791  steps.
# 0.8630156026307996
# Trial  9914  converged in  940  steps.
# 0.8022554931556621
# Trial  9915  converged in  1212  steps.
# 0.9051532911702931
# Trial  9916  converged in  1407  steps.
# 1.1263621737080114
# Trial  9917  converged in  1190  steps.
# 1.2264593062314042
# Trial  9918  converged in  2250  steps.
# 0.9259304900474434
# Trial  9919  converged in  1670  steps.
# 0.9856895026377284
# Trial  9920  converged in  1828  steps.
# 1.3592455010335909
# Trial  9921  converged in  2958  steps.
# 0.5715108769471373
# Trial  9922  converged in  803  steps.
# 1.0643794910460764
# Trial  9923  converged in  1464  steps.
# 0.6316057387263323
# Trial  9924  converged in  749  steps.
# 0.6173281557951337
# Trial  9925  converged in  831  steps.
# 0.8507895350266805
# Trial  9926  converged in  980  steps.
# 1.0199978460309294
# Trial  9927  converged in  1162  steps.
# 1.0641426882129679
# Trial  9928  converged in  1925  steps.
# 0.6008595328643874
# Trial  9929  converged in  946  steps.
# 1.0919057729519122
# Trial  9930  converged in  2029  steps.
# 0.5238850006129736
# Trial  9931  converged in  503  steps.
# 0.8731412923984874
# Trial  9932  converged in  1286  steps.
# 0.5572460124013038
# Trial  9933  converged in  597  steps.
# 0.5880801536374497
# Trial  9934  converged in  601  steps.
# 1.0012598246623032
# Trial  9935  converged in  1603  steps.
# 1.017409973434688
# Trial  9936  converged in  803  steps.
# 0.774125154010538
# Trial  9937  converged in  872  steps.
# 1.1948089009423448
# Trial  9938  converged in  1901  steps.
# 0.39282577806679375
# Trial  9939  converged in  437  steps.
# 0.6436260731376786
# Trial  9940  converged in  390  steps.
# 0.7204424344481551
# Trial  9941  converged in  945  steps.
# 0.802770314980197
# Trial  9942  converged in  1245  steps.
# 0.6067124042863098
# Trial  9943  converged in  873  steps.
# 0.8490391966732367
# Trial  9944  converged in  1215  steps.
# 0.5857460465207334
# Trial  9945  converged in  579  steps.
# 0.7014922979533922
# Trial  9946  converged in  1008  steps.
# 0.9258249531361941
# Trial  9947  converged in  829  steps.
# 0.7948966388272756
# Trial  9948  converged in  1271  steps.
# 0.6631679254478413
# Trial  9949  converged in  717  steps.
# 0.8409796729749031
# Trial  9950  converged in  1169  steps.
# 0.8026716579775431
# Trial  9951  converged in  1148  steps.
# 0.6271708615473812
# Trial  9952  converged in  629  steps.
# 0.5667273648555574
# Trial  9953  converged in  563  steps.
# 0.9099028750374125
# Trial  9954  converged in  1091  steps.
# 0.8198686290522872
# Trial  9955  converged in  1010  steps.
# 0.5676048443331068
# Trial  9956  converged in  616  steps.
# 0.866664050482503
# Trial  9957  converged in  1129  steps.
# 0.8574385939375357
# Trial  9958  converged in  1398  steps.
# 0.7726741881636935
# Trial  9959  converged in  1011  steps.
# 0.7511612820971362
# Trial  9960  converged in  1027  steps.
# 0.557390710178903
# Trial  9961  converged in  478  steps.
# 0.8983004479872506
# Trial  9962  converged in  1167  steps.
# 0.727168398115514
# Trial  9963  converged in  888  steps.
# 0.8411351434558223
# Trial  9964  converged in  1149  steps.
# 0.8875236235727796
# Trial  9965  converged in  1282  steps.
# 0.6970123993811771
# Trial  9966  converged in  1015  steps.
# 0.6197128359654647
# Trial  9967  converged in  789  steps.
# 1.201119167300726
# Trial  9968  converged in  1889  steps.
# 1.1197173083157006
# Trial  9969  converged in  1492  steps.
# 0.4168970182926011
# Trial  9970  converged in  484  steps.
# 0.8765100232057419
# Trial  9971  converged in  1136  steps.
# 1.3348360461794562
# Trial  9972  converged in  2554  steps.
# 0.838081044156372
# Trial  9973  converged in  1304  steps.
# 1.2830682609217239
# Trial  9974  converged in  2445  steps.
# 0.817447410697363
# Trial  9975  converged in  1169  steps.
# 0.6709201482253722
# Trial  9976  converged in  813  steps.
# 0.9239631049499387
# Trial  9977  converged in  1248  steps.
# 0.7833250507893125
# Trial  9978  converged in  1071  steps.
# 1.2247878137210213
# Trial  9979  converged in  1426  steps.
# 1.1430792599257937
# Trial  9980  converged in  2079  steps.
# 1.0436142361816887
# Trial  9981  converged in  1864  steps.
# 1.1623040786023229
# Trial  9982  converged in  1766  steps.
# 1.1555317185373752
# Trial  9983  converged in  1713  steps.
# 1.102588835227024
# Trial  9984  converged in  1862  steps.
# 1.0805689049306202
# Trial  9985  converged in  2086  steps.
# 1.042113955254666
# Trial  9986  converged in  1316  steps.
# 0.5314693792353343
# Trial  9987  converged in  790  steps.
# 0.9855027212648773
# Trial  9988  converged in  1604  steps.
# 0.7057324076431782
# Trial  9989  converged in  827  steps.
# 1.1968416778629871
# Trial  9990  converged in  1927  steps.
# 0.6969445840813219
# Trial  9991  converged in  641  steps.
# 1.214867647194375
# Trial  9992  converged in  1966  steps.
# 0.6081293012833532
# Trial  9993  converged in  776  steps.
# 0.7155387479221205
# Trial  9994  converged in  1105  steps.
# 0.7926332288908414
# Trial  9995  converged in  1107  steps.
# 1.3712471501546857
# Trial  9996  converged in  2385  steps.
# 1.143070001838602
# Trial  9997  converged in  1940  steps.
# 1.1504004928738059
# Trial  9998  converged in  1468  steps.
# 0.8959584914221205
# Trial  9999  converged in  1050  steps.
# 0.7572167845332034
# Trial  10000  converged in  341  steps.

# %%
plot_sigma_hat_histogram(sigma2_hat_vec)
for i in range(len(sigma2_hat_vec)):
    if sigma2_hat_vec[i]>10:
        print(sigma2_hat_vec[i])

# %% [markdown]
# **Question:** Do you recognize the shape of this histogram? What is it?
#
# **Answer:** Yes, this looks like a Gaussian distribution! Maybe we can explain this result by invoking the central limit theorem.

# %% [markdown]
# ### Bias and variance of the *estimator*
# Use *the same* 10,000 repeated trials to numerically estimate the (frequentist) bias and variance of the ML estimate $\hat{\sigma}^2$ of the Gaussian variance parameter.
#
# Compare the results with the theoretical (frequentist) bias and variance that you can compute from the formula you derived in Question 3(d).
#
# *Hint: if your numerical estimates are very far from the theoretical formula, you made a mistake somewhere!*

# %%
sigma2_hat_mean, sigma2_hat_var = freq_mean_var(sigma2_hat_vec)
print(sigma2_hat_mean)

TRUE_SIGMA2 = 1.

# In the next lines, fill in the theoretical bias and variance of $\hat{\sigma}^2$
THEO_BIAS = TRUE_SIGMA2 / NUM_TRIALS
THEO_VAR = 2 * TRUE_SIGMA2 * (NUM_TRIALS -1 ) / NUM_TRIALS**2

emp_bias = empirical_frequentist_bias(empirical_mean=sigma2_hat_mean,
                                      true_mean=TRUE_SIGMA2)

print('Theoretical Bias: ', THEO_BIAS, ' Freq. Estimated Bias: ', emp_bias)
print('Theoretical Variance: ', THEO_VAR, ' Freq. Estimated Variance: ', sigma2_hat_var)
# Out:
# 0.8825935211449036
# Theoretical Bias:  0.0001  Freq. Estimated Bias:  0.11740647885509636
# Theoretical Variance:  0.00019998  Freq. Estimated Variance:  0.04806799785046656

# %% [markdown]
# **Question:** What conclusions can you draw from the result of this comparison?
#
# **Answer:**
